# %% [markdown]
# # 1. Recopilación de los datos

# %%
# !scrapy startproject imdb ../clase/
# Out:
# Error: scrapy.cfg already exists in /home/ruben/Documentos/CE/PIA/Tema 4/Caso practico/clase/clase

# %%
# !cd ../clase/ && scrapy genspider "movies-released-in-2020" "www.imdb.com/search/title/?title_type=feature&release_date=2020-01-01,2020-12-31&runtime=1,&sort=release_date,asc&count=250"
# Out:
# Spider 'movies-released-in-2020' already exists in module:
#   imdb.spiders.movies_released_in_2020

# %%
# !cd
# !cd ../clase && scrapy crawl "movies-released-in-2020"
# Out:
# 2023-02-12 17:24:58 [scrapy.utils.log] INFO: Scrapy 2.7.1 started (bot: imdb)
# 2023-02-12 17:24:58 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 22.10.0, Python 3.9.15 (main, Nov 24 2022, 14:31:59) - [GCC 11.2.0], pyOpenSSL 23.0.0 (OpenSSL 3.0.7 1 Nov 2022), cryptography 39.0.0, Platform Linux-5.15.0-58-generic-x86_64-with-glibc2.35
# 2023-02-12 17:24:58 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'imdb',
#  'NEWSPIDER_MODULE': 'imdb.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['imdb.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-02-12 17:24:58 [asyncio] DEBUG: Using selector: EpollSelector
# 2023-02-12 17:24:58 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# ...

# %% [markdown]
# # 2. Almacenamiento de los datos

# %%
#!mkdir ../datasets
# !cd ../clase && scrapy crawl "movies-released-in-2020" -O ../datasets/dataset.json
# Out:
# 2023-02-12 17:25:06 [scrapy.utils.log] INFO: Scrapy 2.7.1 started (bot: imdb)
# 2023-02-12 17:25:06 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 22.10.0, Python 3.9.15 (main, Nov 24 2022, 14:31:59) - [GCC 11.2.0], pyOpenSSL 23.0.0 (OpenSSL 3.0.7 1 Nov 2022), cryptography 39.0.0, Platform Linux-5.15.0-58-generic-x86_64-with-glibc2.35
# 2023-02-12 17:25:06 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'imdb',
#  'NEWSPIDER_MODULE': 'imdb.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['imdb.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-02-12 17:25:06 [asyncio] DEBUG: Using selector: EpollSelector
# 2023-02-12 17:25:06 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# ...

# %% [markdown]
# # 3. Conversión de los datos

# %%
import pandas as pd

# %%
df = pd.read_json('../datasets/dataset.json')
print(len(df))
df.head()
# Out:
# 749
#                        title    year  duration  \
# 0                   Dolittle  2020.0       101
# 1                 The Grudge  2020.0        94
# 2              Ghost Stories  2020.0       144
# 3                   Invasion  2020.0       134
# 4  Antony and Cleopatra 2020  2020.0        72
#
#                                     genres  rating  \
# 0  \nAdventure, Comedy, Family                 5.6
# 1            \nFantasy, Horror                 4.4
# 2           \nHorror, Thriller                 4.4
# 3             \nAction, Sci-Fi                 5.6
# 4             \nDrama, History                 NaN
#
#                                             synopsis  \
# 0  \nA physician who can talk to animals embarks ...
# 1  \nA house is cursed by a vengeful ghost that d...
# 2  \nThe winning team of "Lust Stories" reunites ...
# 3  \nWith the fall of the alien ship Julia's life...
# 4  \nRomeo and Juliet for adults: a Roman rules a...
#
# ...

# %%
df.to_csv('../datasets/dataset.csv')

# %% [markdown]
# # 4. Inspección de los datos

# %%
print(len(df))
df.head()
# Out:
# 749
#                        title    year  duration  \
# 0                   Dolittle  2020.0       101
# 1                 The Grudge  2020.0        94
# 2              Ghost Stories  2020.0       144
# 3                   Invasion  2020.0       134
# 4  Antony and Cleopatra 2020  2020.0        72
#
#                                     genres  rating  \
# 0  \nAdventure, Comedy, Family                 5.6
# 1            \nFantasy, Horror                 4.4
# 2           \nHorror, Thriller                 4.4
# 3             \nAction, Sci-Fi                 5.6
# 4             \nDrama, History                 NaN
#
#                                             synopsis  \
# 0  \nA physician who can talk to animals embarks ...
# 1  \nA house is cursed by a vengeful ghost that d...
# 2  \nThe winning team of "Lust Stories" reunites ...
# 3  \nWith the fall of the alien ship Julia's life...
# 4  \nRomeo and Juliet for adults: a Roman rules a...
#
# ...

# %%
# !poetry add "pandas-profiling[notebook]"
# Out:
# Using version ^3.6.6 for pandas-profiling
#
# Updating dependencies
# Resolving dependencies... (4.4s)Resolving dependencies... (0.7s)Resolving dependencies... (1.6s)Resolving dependencies... (2.1s)Resolving dependencies... (2.7s)Resolving dependencies... (4.2s)
#
# No dependencies to install or update

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df, explorative=True)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-02-12 16:25:21.840713&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# !mkdir -p reports
profile.to_file('reports/dataset-report.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
